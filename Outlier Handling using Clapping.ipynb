# %%
#importing required libraries
import numpy as np
import pandas as pd

# %%
#reading the csv file
sp=pd.read_csv(r"C:\Users\Satya Narahari\Downloads\1940599-loandata\loandata.csv")

# %%
sp
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
Q1=sp["ApplicantIncome"].quantile(0.25)  #checking the percentages
Q3=sp["ApplicantIncome"].quantile(0.75)
IQR=Q3-Q1         #finding the IQR
LL=Q1-1.5*IQR     #finding the lower limit
UL=Q3+1.5*IQR     #finding the upper limit

# %%
(Q1,Q3,IQR,LL,UL)  #all values
# Out:
# (2877.5, 5795.0, 2917.5, -1498.75, 10171.25)

# %%
sp[sp["ApplicantIncome"]<LL]    #checking the values lesser than lowerlimit
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
sp[sp["ApplicantIncome"]>UL]     #checking the values greater than upperlimit
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 564  LP001422  Female      No          0      Graduate            No
# 565  LP002403    Male      No          0      Graduate           Yes
# 566  LP001451    Male     Yes          1      Graduate           Yes
# 567  LP001233    Male     Yes          1      Graduate            No
# 568  LP002541    Male     Yes          0      Graduate            No
# 569  LP001673    Male      No          0      Graduate           Yes
# 570  LP001891    Male     Yes          0      Graduate            No
# 571  LP002729    Male      No          1      Graduate            No
# 572  LP001369    Male     Yes          2      Graduate            No
# 573  LP001186  Female     Yes          1      Graduate           Yes
# 574  LP001508    Male     Yes          2      Graduate            No
# 575  LP001656    Male      No          0      Graduate            No
# 576  LP002959  Female     Yes          1      Graduate            No
# ...

# %%
sp.loc[sp['ApplicantIncome'] > UL, 'ApplicantIncome'] = UL   #changing the outliers to upperlimit

# %%
sp
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
